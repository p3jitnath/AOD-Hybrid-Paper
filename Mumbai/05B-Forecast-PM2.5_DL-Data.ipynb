# %%
import pickle
import pandas as pd

from glob import glob

# %%
path = "./dl_models"
model_directories = glob(path + "/*/")

# %%
table_dict = {}

for idx in range(len(model_directories)):
    directory = model_directories[idx]
    model_name = directory.split("/")[-2]
    station_pkls = glob(path + "/" + model_name + "/*_pm25.pkl")
    
    model_data = {}

    for inner_idx in range(len(station_pkls)):
        station_data = pickle.load(open(station_pkls[inner_idx], "rb"))
        model_data[station_data["station_id"]] = station_data["score"]
        
    table_dict[model_name] = model_data

# %%
reform = {(outerKey, innerKey): values for outerKey, innerDict in table_dict.items() for innerKey, values in innerDict.items()}

# %%
result_df = pd.DataFrame(reform).transpose()

# %%
result_df
# Out:
#                               r2_score        mae       rmse       mean
# Multi Layer Perceptron MH013  0.448774  17.425692  23.455128  70.144235
#                        MH009  0.477409  16.361954  21.153544  71.369286
#                        MH012  0.308601  19.793266  25.383785  67.191059
#                        MH014 -0.147321  27.426967  35.019965  70.873012
#                        MH007  0.426981  17.344878  22.299920  77.950118
#                        MH008  0.488692  14.501627  18.081403  64.690506
#                        MH006  0.359913  12.992044  16.265163  48.218434
#                        MH011  0.341288  15.186429  19.798830  67.308750
#                        MH010  0.490897  12.911034  16.281857  60.576000
# BiDirectional LSTM     MH013  0.495825  17.171370  22.431777  70.144235
#                        MH009  0.441009  16.432399  21.877841  71.369286
#                        MH012  0.330631  20.319682  24.976117  67.191059
#                        MH014 -0.257719  29.944561  36.666126  70.873012
#                        MH007  0.391326  17.669078  22.983254  77.950118
#                        MH008  0.416711  15.613720  19.312243  64.690506
#                        MH006  0.036382  16.279519  19.956824  48.218434
#                        MH011  0.161059  17.919134  22.343834  67.308750
#                        MH010  0.351265  14.516307  18.379533  60.576000
# LSTM AutoEncoder       MH013  0.494169  17.103409  22.468566  70.144235
#                        MH009  0.438831  16.462182  21.920427  71.369286
#                        MH012  0.318392  20.542688  25.203422  67.191059
#                        MH014 -0.264405  30.440157  36.763459  70.873012
#                        MH007  0.382245  17.686869  23.154064  77.950118
#                        MH008  0.418846  15.558932  19.276871  64.690506
#                        MH006  0.056972  16.145345  19.742468  48.218434
#                        MH011  0.201174  17.577495  21.803085  67.308750
#                        MH010  0.353830  14.523283  18.343173  60.576000

# %%
predictions_df = pd.read_pickle(path + "/MH010_predictions.pkl")

# %%
predictions_df
# Out:
#             Actual  Multi Layer Perceptron  BiDirectional LSTM  \
# 2019-12-23   86.32               75.753075           73.633072
# 2019-12-24   83.66               83.891457           77.891846
# 2019-12-25  108.50               82.094582           77.704964
# 2019-12-26  121.49              104.705910           85.533730
# 2019-12-27   73.82              117.667740           90.446320
# ...            ...                     ...                 ...
# 2020-03-12   15.44               49.312538           65.466331
# 2020-03-13   19.42               28.869740           24.594311
# 2020-03-14   24.96               33.021420           34.376141
# 2020-03-15   28.79               38.498219           47.735893
# 2020-03-16   47.21               42.423233           55.757072
#
#             LSTM AutoEncoder
# 2019-12-23         73.454132
# 2019-12-24         77.416451
# 2019-12-25         77.368141
# 2019-12-26         84.754921
# 2019-12-27         88.625961
# ...                      ...
# 2020-03-12         64.621452
# 2020-03-13         24.536222
# 2020-03-14         33.976643
# 2020-03-15         46.883266
# 2020-03-16         54.830563
#
# [85 rows x 4 columns]
