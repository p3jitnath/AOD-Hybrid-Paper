# %%
import pickle
import pandas as pd

from glob import glob

# %%
path = "./ml_models"
model_directories = glob(path + "/*/")

# %%
table_dict = {}

for idx in range(len(model_directories)):
    directory = model_directories[idx]
    model_name = directory.split("/")[-2]
    station_pkls = glob(path + "/" + model_name + "/*_pm25.pkl")
    
    model_data = {}

    for inner_idx in range(len(station_pkls)):
        station_data = pickle.load(open(station_pkls[inner_idx], "rb"))
        model_data[station_data["station_id"]] = station_data["score"]
        
    table_dict[model_name + " Regression"] = model_data

# %%
reform = {(outerKey, innerKey): values for outerKey, innerDict in table_dict.items() for innerKey, values in innerDict.items()}

# %%
result_df = pd.DataFrame(reform).transpose()

# %%
result_df
# Out:
#                                 r2_score        mae       rmse       mean
# Random Forest Regression MH013  0.448873  17.640520  23.486436  69.818214
#                          MH009  0.502750  15.966014  20.618121  70.996747
#                          MH012  0.395736  17.644694  23.718916  66.815357
#                          MH014  0.323045  20.219623  25.025261  68.851358
#                          MH007  0.537392  15.958408  19.984329  77.183855
#                          MH008  0.519381  13.987627  17.647073  64.240649
#                          MH006  0.536088   9.720475  12.813814  46.971481
#                          MH011  0.198346  17.411235  21.759933  66.629359
#                          MH010  0.505133  12.883571  16.018583  59.987711
# Decision Tree Regression MH013  0.276249  20.040238  26.914481  69.818214
#                          MH009  0.379029  18.655422  23.040784  70.996747
#                          MH012  0.085676  22.226548  29.176388  66.815357
#                          MH014 -0.283991  28.051852  34.465122  68.851358
#                          MH007  0.323620  19.465301  24.164525  77.183855
#                          MH008  0.093939  19.277273  24.229866  64.240649
#                          MH006 -0.458713  17.722469  22.721946  46.971481
#                          MH011 -0.261289  22.261923  27.294266  66.629359
#                          MH010  0.263300  15.602530  19.544529  59.987711
# Linear Regression        MH013  0.498552  16.571531  22.402911  69.818214
#                          MH009  0.517603  16.068107  20.307851  70.996747
#                          MH012  0.391860  18.546242  23.794853  66.815357
#                          MH014  0.419204  17.776843  23.179848  68.851358
#                          MH007  0.527304  16.477224  20.201058  77.183855
#                          MH008  0.520822  13.861689  17.620608  64.240649
#                          MH006  0.543703   9.819509  12.708214  46.971481
#                          MH011  0.392808  14.360158  18.937700  66.629359
#                          MH010  0.518594  12.346355  15.799216  59.987711
# Polynomial Regression    MH013 -2.013305  31.523938  54.917769  69.818214
#                          MH009  0.145462  22.694125  27.028848  70.996747
#                          MH012 -0.624355  30.586846  38.888565  66.815357
#                          MH014 -0.034038  24.039819  30.929088  68.851358
#                          MH007 -1.201679  34.255500  43.597334  77.183855
#                          MH008 -0.137164  21.537252  27.144621  64.240649
#                          MH006  0.253436  12.099019  16.255271  46.971481
#                          MH011  0.073031  17.302405  23.398971  66.629359
#                          MH010 -2.937660  33.302117  45.185501  59.987711
# SVR Regression           MH013  0.355288  19.550040  25.402371  69.818214
#                          MH009  0.344343  19.183584  23.675557  70.996747
#                          MH012  0.398915  17.465990  23.656446  66.815357
#                          MH014  0.456165  18.182630  22.430154  68.851358
#                          MH007  0.370537  19.155562  23.311376  77.183855
#                          MH008  0.489763  13.899370  18.182701  64.240649
#                          MH006  0.388543  11.796192  14.711051  46.971481
#                          MH011  0.377903  14.764699  19.168716  66.629359
#                          MH010  0.369149  14.544041  18.086030  59.987711

# %%
predictions_df = pd.read_pickle(path + "/MH010_predictions.pkl")

# %%
predictions_df
# Out:
#             Actual  SVR Regression  Polynomial Regression  Linear Regression  \
# 2019-12-25  108.50       77.365810              87.274918          83.280776
# 2019-12-26  121.49       75.789672             147.387253         101.121347
# 2019-12-27   73.82       62.453218              95.403290         116.690640
# 2019-12-28   78.20       52.099921              86.691666          67.321682
# 2019-12-29   72.50       54.022605              54.727768          86.417111
# ...            ...             ...                    ...                ...
# 2020-03-12   15.44       42.795220              41.121201          38.660070
# 2020-03-13   19.42       15.803633              13.345444          13.864440
# 2020-03-14   24.96       20.143041               0.777832          24.754721
# 2020-03-15   28.79       25.829299              53.806091          27.678840
# 2020-03-16   47.21       28.035687               1.213776          27.268227
#
#             Decision Tree Regression  Random Forest Regression
# 2019-12-25                     79.12                   76.4007
# 2019-12-26                     83.29                   76.4998
# 2019-12-27                     79.12                   76.0493
# 2019-12-28                     81.64                   69.5750
# 2019-12-29                     71.16                   73.1931
# ...                              ...                       ...
# 2020-03-12                     40.36                   42.2716
# 2020-03-13                     10.91                   15.7901
# 2020-03-14                     12.26                   23.9893
# 2020-03-15                     15.33                   22.8669
# 2020-03-16                     54.56                   38.7337
#
# [83 rows x 6 columns]
