# %%
import pickle
import pandas as pd

from glob import glob

# %%
path = "./ml_models"
model_directories = glob(path + "/*/")

# %%
table_dict = {}

for idx in range(len(model_directories)):
    directory = model_directories[idx]
    model_name = directory.split("/")[-2]
    station_pkls = glob(path + "/" + model_name + "/*_pm25.pkl")
    
    model_data = {}

    for inner_idx in range(len(station_pkls)):
        station_data = pickle.load(open(station_pkls[inner_idx], "rb"))
        model_data[station_data["station_id"]] = station_data["score"]
        
    table_dict[model_name + " Regression"] = model_data

# %%
reform = {(outerKey, innerKey): values for outerKey, innerDict in table_dict.items() for innerKey, values in innerDict.items()}

# %%
result_df = pd.DataFrame(reform).transpose()

# %%
result_df
# Out:
#                                  r2_score        mae        rmse       mean
# Random Forest Regression KA006   0.281994   9.077182   12.495077  34.025753
#                          KA009  -0.100543   9.457005   18.803552  33.160126
#                          KA003   0.013380  22.760590   59.458253  52.356402
#                          KA011   0.500386   7.603270   10.749131  33.198486
#                          KA004   0.263609   8.042813   10.401460  34.798710
#                          KA007   0.505321   8.162637   11.879428  29.917935
#                          KA002   0.154395  11.790272   20.824419  29.380549
# Decision Tree Regression KA006  -0.120579  11.309122   15.609760  34.025753
#                          KA009  -2.731477  11.906527   34.623971  33.160126
#                          KA003  -0.195046  28.283389   65.437927  52.356402
#                          KA011   0.160556  10.280757   13.933231  33.198486
#                          KA004   0.071881   9.511559   11.677281  34.798710
#                          KA007   0.086455  11.423152   16.143530  29.917935
#                          KA002  -0.724785  16.138565   29.741072  29.380549
# Linear Regression        KA006   0.361948   8.343634   11.778853  34.025753
#                          KA009   0.122947  10.469981   16.786085  33.160126
#                          KA003  -0.000840  25.088479   59.885210  52.356402
#                          KA011   0.577145   7.478160    9.888990  33.198486
#                          KA004   0.304769   7.759015   10.106587  34.798710
#                          KA007   0.483531   8.414802   12.138244  29.917935
#                          KA002   0.163174  12.038201   20.716043  29.380549
# Polynomial Regression    KA006  -0.423833  11.913867   17.595616  34.025753
#                          KA009   0.227632   8.651415   15.752468  33.160126
#                          KA003 -25.031957  81.258892  305.415204  52.356402
#                          KA011   0.445995   8.369228   11.319125  33.198486
#                          KA004   0.113010   9.053039   11.415616  34.798710
#                          KA007   0.265556   9.384595   14.474814  29.917935
#                          KA002   0.260743  11.129820   19.470941  29.380549
# SVR Regression           KA006   0.324330   8.643619   12.121110  34.025753
#                          KA009   0.292209   6.722404   15.079566  33.160126
#                          KA003   0.010076  20.875548   59.557735  52.356402
#                          KA011   0.550433   7.478428   10.196555  33.198486
#                          KA004   0.226272   8.383775   10.661891  34.798710
#                          KA007   0.483192   8.703014   12.142218  29.917935
#                          KA002   0.206896   9.589513   20.167604  29.380549

# %%
predictions_df = pd.read_pickle(path + "/KA007_predictions.pkl")

# %%
predictions_df
# Out:
#             Actual  SVR Regression  Polynomial Regression  Linear Regression  \
# 2019-09-15    9.84       12.119297               9.834123          11.300676
# 2019-09-16   11.09       11.125194               9.533702          10.493779
# 2019-09-17    8.30       11.410929              10.372569          12.068938
# 2019-09-18    8.27        9.214897               8.762909           9.542116
# 2019-09-19    8.07        9.147906               8.509396           9.945544
# ...            ...             ...                    ...                ...
# 2020-03-12   35.74       41.301176              41.327644          42.092650
# 2020-03-13   26.51       33.445647              35.321730          35.550738
# 2020-03-14   31.27       28.043642              30.997041          29.262328
# 2020-03-15   24.61       32.994077              34.419592          33.646932
# 2020-03-16   30.51       24.324055              24.354803          24.958032
#
#             Decision Tree Regression  Random Forest Regression
# 2019-09-15                     11.40                   12.6447
# 2019-09-16                     11.43                   11.9555
# 2019-09-17                     11.60                   12.2636
# 2019-09-18                      7.28                    7.7723
# 2019-09-19                     12.56                    9.0848
# ...                              ...                       ...
# 2020-03-12                     62.75                   42.4600
# 2020-03-13                     38.88                   30.5605
# 2020-03-14                     36.86                   32.5784
# 2020-03-15                     53.89                   33.6564
# 2020-03-16                     22.73                   24.4617
#
# [184 rows x 6 columns]
